# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
xdf = pd.read_csv(r'/Users/davidpitoun/RNCP_project/db csv/reportsdf.csv')

# %%
xdf
# Out:
#               ID_DMR                            TYPE DECLARATION  \
# 0       A2021E060183                      Autos, motos, velos...
# 1       G2021E060186   Graffitis, tags, affiches et autocollants
# 2       G2021E060949                      Autos, motos, velos...
# 3       G2021E060973                           Objets abandonnes
# 4       S2021E061788  Activites commerciales et professionnelles
# ...              ...                                         ...
# 940706  A2021H033269                      Autos, motos, velos...
# 940707  G2021H033275                           Objets abandonnes
# 940708  G2021H029981   Graffitis, tags, affiches et autocollants
# 940709  G2021H029984                           Objets abandonnes
# 940710  G2021H030811                           Objets abandonnes
#
#                                     SOUS TYPE DECLARATION  \
# 0                                           Epave de velo
# 1       Affiches, autocollants ou graffitis sur autres...
# ...

# %%
types=xdf.groupby('TYPE DECLARATION')['TYPE DECLARATION'].count()
types
# Out:
# TYPE DECLARATION
# Activites commerciales et professionnelles     31539
# Arbres, vegetaux et animaux                     9352
# Autos, motos, velos...                        124784
# Eau                                             3867
# Eclairage / Electricite                         9497
# Graffitis, tags, affiches et autocollants     258662
# Mobiliers urbains                              18178
# Objets abandonnes                             321016
# Proprete                                      131134
# Voirie et espace public                        32682
# Name: TYPE DECLARATION, dtype: int64

# %%
fifth=xdf['TYPE DECLARATION']
fifth.value_counts().plot(kind='bar')
plt.title('Number of Report types')
# Out:
# Text(0.5, 1.0, 'Proportion of Report types')

# %%
seventh=xdf['SOUS TYPE DECLARATION']
seventh.value_counts().nlargest(5).plot(kind='bar', figsize=(10,6))
plt.title("Reports Subtype in numbers")
# Out:
# Text(0.5, 1.0, 'Reports Subtype in numbers')

# %% [markdown]
# #### third.plot(kind='bar')
# plt.title('Report Occurences by Arrondissement')

# %%
second=xdf.groupby('OUTIL SOURCE')['OUTIL SOURCE'].count()
second.plot(kind='bar')
plt.title('Reporting Tool (Source Type)')4
# Out:
# OUTIL SOURCE
# Android App          498264
# Back Office            4542
# IOS App              324825
# Web page DMRParis    113080
# Name: OUTIL SOURCE, dtype: int64

# %%
second.plot(kind='bar')
plt.title('Reporting Tool (Source Type)')
# Out:
# Text(0.5, 1.0, 'Reporting Tool (Source Type)')

# %%
fourth=xdf['OUTIL SOURCE']
fourth.value_counts().plot(kind='pie')
plt.title('Proportion of Report Sources')
# Out:
# Text(0.5, 1.0, 'Proportion of Report Sources')

# %%
sixth=xdf['INTERVENANT']
sixth.value_counts().nlargest(10).plot(kind='bar', figsize=(10,6))
plt.title("Most Sollicited city's Services")
# Out:
# Text(0.5, 1.0, "Proportion of city's Intervening Services")
