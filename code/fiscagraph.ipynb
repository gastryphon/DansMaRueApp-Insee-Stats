# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import seaborn as sns

# %%
df1 = pd.read_csv(r'/Users/davidpitoun/RNCP_project/db csv/fiscaldf.csv')

# %%
df2 = pd.read_csv(r'/Users/davidpitoun/RNCP_project/db csv/locationsdf.csv')

# %%
df1=df1.drop(['Unnamed: 0'], axis=1)

# %%
df = pd.read_csv(r'/Users/davidpitoun/RNCP_project/db csv/socioecodf.csv')

# %%
df4 = pd.merge(df1,df2,on='Arrondissement')
# Out:
#     Arrondissement  Mediane du niveau de vie 2018  Emplois Salaries 2017  \
# 0               19                        20900.0                78065.9
# 1                1                        34350.0                55232.7
# 2               11                        28530.0                63826.4
# 3               14                        28340.0                70723.8
# 4                8                        43520.0               155268.7
# 5               16                        40400.0                96535.4
# 6                3                        33060.0                25457.8
# 7               15                        31760.0               158787.1
# 8                2                        32700.0                55557.2
# 9                5                        34250.0                46459.4
# 10              10                        27420.0                71481.5
# 11              17                        31940.0                88978.7
# ...

# %%
sns.regplot(x="Mediane du niveau de vie 2018", y="Part des menages fiscaux imposes 2018",data=df4)
# Out:
# <AxesSubplot:xlabel='Mediane du niveau de vie 2018', ylabel='Part des menages fiscaux imposes 2018'>

# %%
sns.regplot(x="Mediane du niveau de vie 2018", y="Part des menages fiscaux imposes 2018",data=df4)
# Out:
# <AxesSubplot:xlabel='Mediane du niveau de vie 2018', ylabel='Part des menages fiscaux imposes 2018'>

# %%
sns.barplot(x="Arrondissement", y="Part des menages fiscaux imposes 2018",data=df4)
# Out:
# <AxesSubplot:xlabel='Arrondissement', ylabel='Part des menages fiscaux imposes 2018'>

# %%
r=sns.regplot(x="Mediane du niveau de vie 2018", y="Emplois Salaries 2017",data=df4).set(
    title="Relationship between Standard of Living and Employment")

# %%
r=sns.regplot(x="Commerces, transports et services divers 2018", y="Part des menages fiscaux imposes 2018",data=df4).set(
    title="Relationship between Shops & Services Count and share of Taxed Households per Neighborhood")

# %%
result
# Out:
#     Arrondissement  Menages fiscaux 2018  \
# 0             19.0               78988.0
# 1              1.0                8509.0
# 2             11.0               75253.0
# 3             14.0               63432.0
# 4              8.0               17472.0
# 5             16.0               73669.0
# 6              3.0               17723.0
# 7             15.0              111646.0
# 8              2.0               11629.0
# 9              5.0               25981.0
# 10            10.0               44605.0
# 11            17.0               80896.0
# 12            18.0               91254.0
# 13             7.0               24129.0
# 14            12.0               68320.0
# 15             9.0               29658.0
# 16             4.0               13979.0
# 17             6.0               18434.0
# 18            13.0               80357.0
# 19            20.0               89787.0
# 0              NaN                   NaN
# 1              NaN                   NaN
# ...
