# %%
init[['A', 'B']] = init['Coordonnées Lat/Long'].str.split(',', 1, expand=True)

# %%
coord=init[['A', 'B']]

# %%
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.preprocessing import MinMaxScaler, StandardScaler
img = Image.open(r'/Users/davidpitoun/vector-city-map-paris-black-white-france-simple-style-128559056.jpeg')
min_max_scaler = MinMaxScaler()
coord = pd.DataFrame(min_max_scaler.fit_transform(coord), columns=coord.columns)
ax=plt.figure(figsize=(10,12))
plt.axis('off')
plt.imshow(img, extent=(0.1, 0.95, -0.02, 1.1))
plt.scatter(x=coord['B'], y=coord['A'], s=0.01)#, #c='#57DB80', alpha=0.5)
plt.title("DMR App Report Paris")
plt.savefig('mapdmr1.png', bbox_inches='tight')
